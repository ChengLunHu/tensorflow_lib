# %%
import tensorflow as tf
import numpy as np
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

# Import MINST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/tmp/data/", one_hot=True)
# Out:
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz

# %%
# Parameters
learning_rate = 0.001
training_iters = 200000
batch_size = 128
display_step = 10

# %%
# Network Parameters
n_input = 784 # MNIST data input (img shape: 28*28)
n_classes = 10 # MNIST total classes (0-9 digits)
#dropout = 0.75 # Dropout, probability to keep units
dropout = 0.50 # Dropout, probability to keep units

# tf Graph input
x = tf.placeholder(tf.float32, [None, n_input])
y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32) #dropout (keep probability)


# Create some wrappers for simplicity
def conv2d(x, W, b, strides=1):
    # Conv2D wrapper, with bias and relu activation
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)


def maxpool2d(x, k=2):
    # MaxPool2D wrapper
    return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1],
                          padding='SAME')


# Create model
def conv_net(x, weights, biases, dropout):
    # Reshape input picture
    x = tf.reshape(x, shape=[-1, 28, 28, 1])

    # Convolution Layer
    conv1 = conv2d(x, weights['wc1'], biases['bc1'])
    # Max Pooling (down-sampling)
    conv1 = maxpool2d(conv1, k=2)

    # Convolution Layer
    conv2 = conv2d(conv1, weights['wc2'], biases['bc2'])
    # Max Pooling (down-sampling)
    conv2 = maxpool2d(conv2, k=2)

    # Fully connected layer
    # Reshape conv2 output to fit fully connected layer input
    fc1 = tf.reshape(conv2, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    # Apply Dropout
    fc1 = tf.nn.dropout(fc1, dropout)

    # Output, class prediction
    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    return out

# Store layers weight & bias
weights = {
    # 5x5 conv, 1 input, 32 outputs
    'wc1': tf.Variable(tf.random_normal([5, 5, 1, 32])),
    # 5x5 conv, 32 inputs, 64 outputs
    'wc2': tf.Variable(tf.random_normal([5, 5, 32, 64])),
    # fully connected, 7*7*64 inputs, 1024 outputs
    'wd1': tf.Variable(tf.random_normal([7*7*64, 1024])),
    # 1024 inputs, 10 outputs (class prediction)
    'out': tf.Variable(tf.random_normal([1024, n_classes]))
}

biases = {
    'bc1': tf.Variable(tf.random_normal([32])),
    'bc2': tf.Variable(tf.random_normal([64])),
    'bd1': tf.Variable(tf.random_normal([1024])),
    'out': tf.Variable(tf.random_normal([n_classes]))
}

# %%
# Construct model
pred = conv_net(x, weights, biases, keep_prob)

# Define loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(pred, y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# Evaluate model
correct_pred = tf.equal(tf.argmax(pred, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initializing the variables
init = tf.initialize_all_variables()

# %%
# Launch the graph
with tf.Session() as sess:
    sess.run(init)
    step = 1
    # Keep training until reach max iterations
    while step * batch_size < training_iters:
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Run optimization op (backprop)
        sess.run(optimizer, feed_dict={x: batch_x, y: batch_y,
                                       keep_prob: dropout})
        if step % display_step == 0:
            # Calculate batch loss and accuracy
            loss, acc = sess.run([cost, accuracy], feed_dict={x: batch_x,
                                                              y: batch_y,
                                                              keep_prob: 1.})
            print "Iter " + str(step*batch_size) + ", Minibatch Loss= " + \
                  "{:.6f}".format(loss) + ", Training Accuracy= " + \
                  "{:.5f}".format(acc)
                    
            #if ((acc > 0.992) & (loss < 150)):
            #    break;
        step += 1
    print "Optimization Finished!"

    # Calculate accuracy for 256 mnist test images
    print "Testing Accuracy:", \
        sess.run(accuracy, feed_dict={x: mnist.test.images[:256],
                                      y: mnist.test.labels[:256],
                                      keep_prob: 1.})
# Out:
# Iter 1280, Minibatch Loss= 24191.837891, Training Accuracy= 0.27344
# Iter 2560, Minibatch Loss= 8673.187500, Training Accuracy= 0.58594
# Iter 3840, Minibatch Loss= 5776.133301, Training Accuracy= 0.75000
# Iter 5120, Minibatch Loss= 6228.995117, Training Accuracy= 0.66406
# Iter 6400, Minibatch Loss= 4670.009766, Training Accuracy= 0.80469
# Iter 7680, Minibatch Loss= 2254.953613, Training Accuracy= 0.84375
# Iter 8960, Minibatch Loss= 2248.151611, Training Accuracy= 0.84375
# Iter 10240, Minibatch Loss= 1554.526611, Training Accuracy= 0.89062
# Iter 11520, Minibatch Loss= 2602.088867, Training Accuracy= 0.85938
# Iter 12800, Minibatch Loss= 4465.291992, Training Accuracy= 0.82031
# Iter 14080, Minibatch Loss= 2583.809570, Training Accuracy= 0.88281
# Iter 15360, Minibatch Loss= 1565.364258, Training Accuracy= 0.91406
# Iter 16640, Minibatch Loss= 1459.307617, Training Accuracy= 0.87500
# Iter 17920, Minibatch Loss= 2713.270020, Training Accuracy= 0.88281
# Iter 19200, Minibatch Loss= 2810.067383, Training Accuracy= 0.85156
# Iter 20480, Minibatch Loss= 2139.592773, Training Accuracy= 0.87500
# Iter 21760, Minibatch Loss= 1552.576904, Training Accuracy= 0.91406
# Iter 23040, Minibatch Loss= 1448.165039, Training Accuracy= 0.91406
# Iter 24320, Minibatch Loss= 952.780945, Training Accuracy= 0.90625
# Iter 25600, Minibatch Loss= 1756.719971, Training Accuracy= 0.87500
# Iter 26880, Minibatch Loss= 1047.725464, Training Accuracy= 0.91406
# Iter 28160, Minibatch Loss= 1289.379883, Training Accuracy= 0.87500
# Iter 29440, Minibatch Loss= 1279.570557, Training Accuracy= 0.91406
# Iter 30720, Minibatch Loss= 804.101074, Training Accuracy= 0.93750
# Iter 32000, Minibatch Loss= 94.975311, Training Accuracy= 0.99219
# Iter 33280, Minibatch Loss= 1133.997559, Training Accuracy= 0.92969
# Iter 34560, Minibatch Loss= 1388.722290, Training Accuracy= 0.89844
# Iter 35840, Minibatch Loss= 804.706543, Training Accuracy= 0.94531
# Iter 37120, Minibatch Loss= 766.986938, Training Accuracy= 0.93750
# Iter 38400, Minibatch Loss= 498.922119, Training Accuracy= 0.93750
# Iter 39680, Minibatch Loss= 256.166199, Training Accuracy= 0.95312
# Iter 40960, Minibatch Loss= 792.853760, Training Accuracy= 0.94531
# Iter 42240, Minibatch Loss= 760.850098, Training Accuracy= 0.96094
# Iter 43520, Minibatch Loss= 366.580017, Training Accuracy= 0.96875
# Iter 44800, Minibatch Loss= 1041.924316, Training Accuracy= 0.94531
# Iter 46080, Minibatch Loss= 227.246536, Training Accuracy= 0.96875
# Iter 47360, Minibatch Loss= 728.465454, Training Accuracy= 0.96875
# Iter 48640, Minibatch Loss= 1650.928101, Training Accuracy= 0.92969
# Iter 49920, Minibatch Loss= 1109.772217, Training Accuracy= 0.92188
# Iter 51200, Minibatch Loss= 256.356934, Training Accuracy= 0.94531
# Iter 52480, Minibatch Loss= 866.050110, Training Accuracy= 0.94531
# Iter 53760, Minibatch Loss= 879.559082, Training Accuracy= 0.93750
# Iter 55040, Minibatch Loss= 486.045349, Training Accuracy= 0.95312
# Iter 56320, Minibatch Loss= 969.877136, Training Accuracy= 0.95312
# Iter 57600, Minibatch Loss= 636.285400, Training Accuracy= 0.92188
# Iter 58880, Minibatch Loss= 853.182739, Training Accuracy= 0.92969
# Iter 60160, Minibatch Loss= 1185.061157, Training Accuracy= 0.92969
# Iter 61440, Minibatch Loss= 1369.172363, Training Accuracy= 0.92969
# Iter 62720, Minibatch Loss= 948.960754, Training Accuracy= 0.92969
# Iter 64000, Minibatch Loss= 124.980713, Training Accuracy= 0.97656
# Iter 65280, Minibatch Loss= 785.855713, Training Accuracy= 0.92188
# Iter 66560, Minibatch Loss= 872.524292, Training Accuracy= 0.92188
# Iter 67840, Minibatch Loss= 406.022827, Training Accuracy= 0.95312
# Iter 69120, Minibatch Loss= 171.738800, Training Accuracy= 0.96875
# Iter 70400, Minibatch Loss= 550.141418, Training Accuracy= 0.93750
# Iter 71680, Minibatch Loss= 230.556259, Training Accuracy= 0.95312
# Iter 72960, Minibatch Loss= 43.246506, Training Accuracy= 0.97656
# Iter 74240, Minibatch Loss= 500.020691, Training Accuracy= 0.93750
# Iter 75520, Minibatch Loss= 420.695312, Training Accuracy= 0.94531
# Iter 76800, Minibatch Loss= 647.680481, Training Accuracy= 0.94531
# Iter 78080, Minibatch Loss= 24.321060, Training Accuracy= 0.98438
# Iter 79360, Minibatch Loss= 380.296448, Training Accuracy= 0.96094
# Iter 80640, Minibatch Loss= 595.697571, Training Accuracy= 0.94531
# Iter 81920, Minibatch Loss= 485.633514, Training Accuracy= 0.95312
# Iter 83200, Minibatch Loss= 374.760132, Training Accuracy= 0.93750
# Iter 84480, Minibatch Loss= 196.208893, Training Accuracy= 0.96094
# Iter 85760, Minibatch Loss= 216.566422, Training Accuracy= 0.96094
# Iter 87040, Minibatch Loss= 184.202866, Training Accuracy= 0.96094
# Iter 88320, Minibatch Loss= 318.909363, Training Accuracy= 0.94531
# Iter 89600, Minibatch Loss= 161.096741, Training Accuracy= 0.96094
# Iter 90880, Minibatch Loss= 257.934906, Training Accuracy= 0.95312
# Iter 92160, Minibatch Loss= 356.083038, Training Accuracy= 0.98438
# Iter 93440, Minibatch Loss= 235.777069, Training Accuracy= 0.93750
# Iter 94720, Minibatch Loss= 387.688965, Training Accuracy= 0.96094
# Iter 96000, Minibatch Loss= 8.709457, Training Accuracy= 0.99219
# Iter 97280, Minibatch Loss= 424.130829, Training Accuracy= 0.95312
# Iter 98560, Minibatch Loss= 146.802231, Training Accuracy= 0.96875
# Iter 99840, Minibatch Loss= 471.848175, Training Accuracy= 0.94531
# Iter 101120, Minibatch Loss= 264.265961, Training Accuracy= 0.95312
# Iter 102400, Minibatch Loss= 414.852356, Training Accuracy= 0.95312
# Iter 103680, Minibatch Loss= 672.338501, Training Accuracy= 0.91406
# Iter 104960, Minibatch Loss= 72.250832, Training Accuracy= 0.98438
# Iter 106240, Minibatch Loss= 80.003189, Training Accuracy= 0.97656
# Iter 107520, Minibatch Loss= 92.593781, Training Accuracy= 0.98438
# Iter 108800, Minibatch Loss= 512.645325, Training Accuracy= 0.96094
# Iter 110080, Minibatch Loss= 76.294899, Training Accuracy= 0.96875
# Iter 111360, Minibatch Loss= 265.391418, Training Accuracy= 0.94531
# Iter 112640, Minibatch Loss= 84.425621, Training Accuracy= 0.97656
# Iter 113920, Minibatch Loss= 223.141190, Training Accuracy= 0.95312
# Iter 115200, Minibatch Loss= 105.818871, Training Accuracy= 0.96875
# Iter 116480, Minibatch Loss= 47.367748, Training Accuracy= 0.99219
# Iter 117760, Minibatch Loss= 83.512794, Training Accuracy= 0.98438
# Iter 119040, Minibatch Loss= 329.153900, Training Accuracy= 0.94531
# Iter 120320, Minibatch Loss= 136.920776, Training Accuracy= 0.95312
# Iter 121600, Minibatch Loss= 384.213348, Training Accuracy= 0.96875
# Iter 122880, Minibatch Loss= 46.734505, Training Accuracy= 0.98438
# Iter 124160, Minibatch Loss= 196.784363, Training Accuracy= 0.94531
# Iter 125440, Minibatch Loss= 187.869232, Training Accuracy= 0.95312
# Iter 126720, Minibatch Loss= 53.449821, Training Accuracy= 0.96875
# Iter 128000, Minibatch Loss= 164.129318, Training Accuracy= 0.94531
# Iter 129280, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 130560, Minibatch Loss= 206.366852, Training Accuracy= 0.96094
# Iter 131840, Minibatch Loss= 75.349991, Training Accuracy= 0.97656
# Iter 133120, Minibatch Loss= 17.794769, Training Accuracy= 0.98438
# Iter 134400, Minibatch Loss= 360.118042, Training Accuracy= 0.96094
# Iter 135680, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 136960, Minibatch Loss= 245.411591, Training Accuracy= 0.96094
# Iter 138240, Minibatch Loss= 271.682556, Training Accuracy= 0.96875
# Iter 139520, Minibatch Loss= 121.886185, Training Accuracy= 0.96094
# Iter 140800, Minibatch Loss= 434.033325, Training Accuracy= 0.93750
# Iter 142080, Minibatch Loss= 91.682121, Training Accuracy= 0.97656
# Iter 143360, Minibatch Loss= 218.477142, Training Accuracy= 0.96094
# Iter 144640, Minibatch Loss= 71.195175, Training Accuracy= 0.96875
# Iter 145920, Minibatch Loss= 58.094055, Training Accuracy= 0.99219
# Iter 147200, Minibatch Loss= 71.360497, Training Accuracy= 0.98438
# Iter 148480, Minibatch Loss= 392.443024, Training Accuracy= 0.96094
# Iter 149760, Minibatch Loss= 219.694519, Training Accuracy= 0.96094
# Iter 151040, Minibatch Loss= 32.610737, Training Accuracy= 0.97656
# Iter 152320, Minibatch Loss= 93.928772, Training Accuracy= 0.97656
# Iter 153600, Minibatch Loss= 139.931458, Training Accuracy= 0.96875
# Iter 154880, Minibatch Loss= 110.707008, Training Accuracy= 0.96094
# Iter 156160, Minibatch Loss= 91.936653, Training Accuracy= 0.97656
# Iter 157440, Minibatch Loss= 177.787781, Training Accuracy= 0.97656
# Iter 158720, Minibatch Loss= 100.951263, Training Accuracy= 0.96094
# Iter 160000, Minibatch Loss= 172.248947, Training Accuracy= 0.96094
# Iter 161280, Minibatch Loss= 62.689785, Training Accuracy= 0.96875
# Iter 162560, Minibatch Loss= 57.285385, Training Accuracy= 0.97656
# Iter 163840, Minibatch Loss= 17.885109, Training Accuracy= 0.98438
# Iter 165120, Minibatch Loss= 104.877510, Training Accuracy= 0.96875
# Iter 166400, Minibatch Loss= 137.557495, Training Accuracy= 0.97656
# Iter 167680, Minibatch Loss= 136.522873, Training Accuracy= 0.96875
# Iter 168960, Minibatch Loss= 200.860046, Training Accuracy= 0.96875
# Iter 170240, Minibatch Loss= 89.674225, Training Accuracy= 0.96875
# Iter 171520, Minibatch Loss= 124.758720, Training Accuracy= 0.97656
# Iter 172800, Minibatch Loss= 469.503174, Training Accuracy= 0.93750
# Iter 174080, Minibatch Loss= 145.822739, Training Accuracy= 0.96875
# Iter 175360, Minibatch Loss= 159.016571, Training Accuracy= 0.96094
# Iter 176640, Minibatch Loss= 113.732285, Training Accuracy= 0.97656
# Iter 177920, Minibatch Loss= 156.851471, Training Accuracy= 0.97656
# Iter 179200, Minibatch Loss= 190.408157, Training Accuracy= 0.98438
# Iter 180480, Minibatch Loss= 119.533524, Training Accuracy= 0.96094
# Iter 181760, Minibatch Loss= 133.093369, Training Accuracy= 0.96875
# Iter 183040, Minibatch Loss= 75.143585, Training Accuracy= 0.97656
# Iter 184320, Minibatch Loss= 90.238815, Training Accuracy= 0.94531
# Iter 185600, Minibatch Loss= 2.348042, Training Accuracy= 0.99219
# Iter 186880, Minibatch Loss= 81.562485, Training Accuracy= 0.96094
# Iter 188160, Minibatch Loss= 165.666473, Training Accuracy= 0.96875
# Iter 189440, Minibatch Loss= 74.288834, Training Accuracy= 0.96875
# Iter 190720, Minibatch Loss= 126.650513, Training Accuracy= 0.96875
# Iter 192000, Minibatch Loss= 154.267426, Training Accuracy= 0.95312
# Iter 193280, Minibatch Loss= 137.580658, Training Accuracy= 0.97656
# Iter 194560, Minibatch Loss= 150.536926, Training Accuracy= 0.95312
# Iter 195840, Minibatch Loss= 69.994263, Training Accuracy= 0.98438
# Iter 197120, Minibatch Loss= 63.763889, Training Accuracy= 0.97656
# Iter 198400, Minibatch Loss= 173.248962, Training Accuracy= 0.97656
# Iter 199680, Minibatch Loss= 105.181488, Training Accuracy= 0.96875
# Optimization Finished!
# Testing Accuracy: 0.976562
