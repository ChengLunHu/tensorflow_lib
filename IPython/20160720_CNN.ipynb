# %%
import tensorflow as tf
import numpy as np
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

# Import MINST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/tmp/data/", one_hot=True)
# Out:
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz

# %%
# Parameters
#learning_rate = 0.0005
#learning_rate = 0.001
learning_rate = 0.002
training_iters = 200000
batch_size = 128
display_step = 10

# %%
# Network Parameters
n_input = 784 # MNIST data input (img shape: 28*28)
n_classes = 10 # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units
#dropout = 0.50 # Dropout, probability to keep units

# tf Graph input
x = tf.placeholder(tf.float32, [None, n_input])
y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32) #dropout (keep probability)


# Create some wrappers for simplicity
def conv2d(x, W, b, strides=1):
    # Conv2D wrapper, with bias and relu activation
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)


def maxpool2d(x, k=2):
    # MaxPool2D wrapper
    return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1],
                          padding='SAME')


# Create model
def conv_net(x, weights, biases, dropout):
    # Reshape input picture
    x = tf.reshape(x, shape=[-1, 28, 28, 1])

    # Convolution Layer
    conv1 = conv2d(x, weights['wc1'], biases['bc1'])
    # Max Pooling (down-sampling)
    conv1 = maxpool2d(conv1, k=2)

    # Convolution Layer
    conv2 = conv2d(conv1, weights['wc2'], biases['bc2'])
    # Max Pooling (down-sampling)
    conv2 = maxpool2d(conv2, k=2)

    # Fully connected layer
    # Reshape conv2 output to fit fully connected layer input
    fc1 = tf.reshape(conv2, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    # Apply Dropout
    fc1 = tf.nn.dropout(fc1, dropout)

    # Output, class prediction
    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    return out

# Store layers weight & bias
weights = {
    # 5x5 conv, 1 input, 32 outputs
    'wc1': tf.Variable(tf.random_normal([5, 5, 1, 32])),
    # 5x5 conv, 32 inputs, 64 outputs
    'wc2': tf.Variable(tf.random_normal([5, 5, 32, 64])),
    # fully connected, 7*7*64 inputs, 1024 outputs
    'wd1': tf.Variable(tf.random_normal([7*7*64, 1024])),
    # 1024 inputs, 10 outputs (class prediction)
    'out': tf.Variable(tf.random_normal([1024, n_classes]))
}

biases = {
    'bc1': tf.Variable(tf.random_normal([32])),
    'bc2': tf.Variable(tf.random_normal([64])),
    'bd1': tf.Variable(tf.random_normal([1024])),
    'out': tf.Variable(tf.random_normal([n_classes]))
}

# %%
# Construct model
pred = conv_net(x, weights, biases, keep_prob)

# Define loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(pred, y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# Evaluate model
correct_pred = tf.equal(tf.argmax(pred, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initializing the variables
init = tf.initialize_all_variables()

# %%
# Launch the graph
with tf.Session() as sess:
    sess.run(init)
    step = 1
    # Keep training until reach max iterations
    while step * batch_size < training_iters:
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Run optimization op (backprop)
        sess.run(optimizer, feed_dict={x: batch_x, y: batch_y,
                                       keep_prob: dropout})
        if step % display_step == 0:
            # Calculate batch loss and accuracy
            loss, acc = sess.run([cost, accuracy], feed_dict={x: batch_x,
                                                              y: batch_y,
                                                              keep_prob: 1.})
            print "Iter " + str(step*batch_size) + ", Minibatch Loss= " + \
                  "{:.6f}".format(loss) + ", Training Accuracy= " + \
                  "{:.5f}".format(acc)
            
            #tmp00=sess.run(accuracy, feed_dict={x: mnist.test.images[:256],
            #                          y: mnist.test.labels[:256],
            #                          keep_prob: 1.})
            #if (tmp00>0.9920):
            #    break;
        step += 1
    print "Optimization Finished!"

    # Calculate accuracy for 256 mnist test images
    print "Testing Accuracy:", \
        sess.run(accuracy, feed_dict={x: mnist.test.images[:256],
                                      y: mnist.test.labels[:256],
                                      keep_prob: 1.})
# Out:
# Iter 1280, Minibatch Loss= 10774.517578, Training Accuracy= 0.41406
# Iter 2560, Minibatch Loss= 6208.746582, Training Accuracy= 0.62500
# Iter 3840, Minibatch Loss= 3140.498535, Training Accuracy= 0.76562
# Iter 5120, Minibatch Loss= 2560.077393, Training Accuracy= 0.82812
# Iter 6400, Minibatch Loss= 1069.002441, Training Accuracy= 0.92188
# Iter 7680, Minibatch Loss= 861.353394, Training Accuracy= 0.91406
# Iter 8960, Minibatch Loss= 645.658386, Training Accuracy= 0.92969
# Iter 10240, Minibatch Loss= 1398.853638, Training Accuracy= 0.91406
# Iter 11520, Minibatch Loss= 1188.931152, Training Accuracy= 0.89062
# Iter 12800, Minibatch Loss= 1092.845947, Training Accuracy= 0.87500
# Iter 14080, Minibatch Loss= 686.138672, Training Accuracy= 0.92969
# Iter 15360, Minibatch Loss= 630.481934, Training Accuracy= 0.91406
# Iter 16640, Minibatch Loss= 1395.556396, Training Accuracy= 0.89062
# Iter 17920, Minibatch Loss= 734.692688, Training Accuracy= 0.92969
# Iter 19200, Minibatch Loss= 831.802856, Training Accuracy= 0.92969
# Iter 20480, Minibatch Loss= 924.458435, Training Accuracy= 0.92188
# Iter 21760, Minibatch Loss= 1124.029297, Training Accuracy= 0.89844
# Iter 23040, Minibatch Loss= 998.872925, Training Accuracy= 0.90625
# Iter 24320, Minibatch Loss= 606.790161, Training Accuracy= 0.92969
# Iter 25600, Minibatch Loss= 671.826599, Training Accuracy= 0.94531
# Iter 26880, Minibatch Loss= 813.064697, Training Accuracy= 0.91406
# Iter 28160, Minibatch Loss= 59.782059, Training Accuracy= 0.98438
# Iter 29440, Minibatch Loss= 647.216003, Training Accuracy= 0.93750
# Iter 30720, Minibatch Loss= 168.653214, Training Accuracy= 0.96094
# Iter 32000, Minibatch Loss= 574.398499, Training Accuracy= 0.95312
# Iter 33280, Minibatch Loss= 182.891785, Training Accuracy= 0.96875
# Iter 34560, Minibatch Loss= 226.537308, Training Accuracy= 0.97656
# Iter 35840, Minibatch Loss= 417.702698, Training Accuracy= 0.92969
# Iter 37120, Minibatch Loss= 185.025269, Training Accuracy= 0.96875
# Iter 38400, Minibatch Loss= 243.179611, Training Accuracy= 0.94531
# Iter 39680, Minibatch Loss= 829.287109, Training Accuracy= 0.93750
# Iter 40960, Minibatch Loss= 698.780579, Training Accuracy= 0.90625
# Iter 42240, Minibatch Loss= 602.862305, Training Accuracy= 0.94531
# Iter 43520, Minibatch Loss= 33.742836, Training Accuracy= 0.99219
# Iter 44800, Minibatch Loss= 476.322571, Training Accuracy= 0.96875
# Iter 46080, Minibatch Loss= 168.247620, Training Accuracy= 0.97656
# Iter 47360, Minibatch Loss= 148.705307, Training Accuracy= 0.96875
# Iter 48640, Minibatch Loss= 355.873779, Training Accuracy= 0.96094
# Iter 49920, Minibatch Loss= 338.991455, Training Accuracy= 0.92969
# Iter 51200, Minibatch Loss= 295.071594, Training Accuracy= 0.96094
# Iter 52480, Minibatch Loss= 157.715637, Training Accuracy= 0.96875
# Iter 53760, Minibatch Loss= 93.078758, Training Accuracy= 0.97656
# Iter 55040, Minibatch Loss= 312.139435, Training Accuracy= 0.96094
# Iter 56320, Minibatch Loss= 183.257019, Training Accuracy= 0.95312
# Iter 57600, Minibatch Loss= 498.870026, Training Accuracy= 0.94531
# Iter 58880, Minibatch Loss= 304.423767, Training Accuracy= 0.96094
# Iter 60160, Minibatch Loss= 204.758286, Training Accuracy= 0.95312
# Iter 61440, Minibatch Loss= 165.325958, Training Accuracy= 0.96094
# Iter 62720, Minibatch Loss= 136.763489, Training Accuracy= 0.98438
# Iter 64000, Minibatch Loss= 48.819618, Training Accuracy= 0.97656
# Iter 65280, Minibatch Loss= 122.758553, Training Accuracy= 0.98438
# Iter 66560, Minibatch Loss= 337.345856, Training Accuracy= 0.95312
# Iter 67840, Minibatch Loss= 94.152008, Training Accuracy= 0.97656
# Iter 69120, Minibatch Loss= 35.930450, Training Accuracy= 0.98438
# Iter 70400, Minibatch Loss= 330.298340, Training Accuracy= 0.94531
# Iter 71680, Minibatch Loss= 8.236473, Training Accuracy= 0.98438
# Iter 72960, Minibatch Loss= 319.189056, Training Accuracy= 0.95312
# Iter 74240, Minibatch Loss= 60.660217, Training Accuracy= 0.97656
# Iter 75520, Minibatch Loss= 98.092422, Training Accuracy= 0.98438
# Iter 76800, Minibatch Loss= 82.981308, Training Accuracy= 0.97656
# Iter 78080, Minibatch Loss= 167.804993, Training Accuracy= 0.95312
# Iter 79360, Minibatch Loss= 400.686371, Training Accuracy= 0.94531
# Iter 80640, Minibatch Loss= 71.973724, Training Accuracy= 0.98438
# Iter 81920, Minibatch Loss= 4.309708, Training Accuracy= 0.99219
# Iter 83200, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 84480, Minibatch Loss= 290.424377, Training Accuracy= 0.95312
# Iter 85760, Minibatch Loss= 280.066223, Training Accuracy= 0.98438
# Iter 87040, Minibatch Loss= 149.821945, Training Accuracy= 0.96094
# Iter 88320, Minibatch Loss= 26.702972, Training Accuracy= 0.99219
# Iter 89600, Minibatch Loss= 8.449959, Training Accuracy= 0.99219
# Iter 90880, Minibatch Loss= 189.985779, Training Accuracy= 0.98438
# Iter 92160, Minibatch Loss= 232.254395, Training Accuracy= 0.96094
# Iter 93440, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 94720, Minibatch Loss= 56.138557, Training Accuracy= 0.96875
# Iter 96000, Minibatch Loss= 59.483284, Training Accuracy= 0.98438
# Iter 97280, Minibatch Loss= 36.753098, Training Accuracy= 0.99219
# Iter 98560, Minibatch Loss= 76.033142, Training Accuracy= 0.96094
# Iter 99840, Minibatch Loss= 162.217667, Training Accuracy= 0.96094
# Iter 101120, Minibatch Loss= 225.510834, Training Accuracy= 0.95312
# Iter 102400, Minibatch Loss= 74.846725, Training Accuracy= 0.95312
# Iter 103680, Minibatch Loss= 311.535767, Training Accuracy= 0.95312
# Iter 104960, Minibatch Loss= 188.195374, Training Accuracy= 0.96094
# Iter 106240, Minibatch Loss= 234.889404, Training Accuracy= 0.95312
# Iter 107520, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 108800, Minibatch Loss= 48.948952, Training Accuracy= 0.98438
# Iter 110080, Minibatch Loss= 45.828766, Training Accuracy= 0.96094
# Iter 111360, Minibatch Loss= 121.783890, Training Accuracy= 0.96094
# Iter 112640, Minibatch Loss= 114.718864, Training Accuracy= 0.97656
# Iter 113920, Minibatch Loss= 42.934906, Training Accuracy= 0.96875
# Iter 115200, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 116480, Minibatch Loss= 56.062538, Training Accuracy= 0.97656
# Iter 117760, Minibatch Loss= 408.615845, Training Accuracy= 0.94531
# Iter 119040, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 120320, Minibatch Loss= 68.498222, Training Accuracy= 0.96875
# Iter 121600, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 122880, Minibatch Loss= 34.069027, Training Accuracy= 0.98438
# Iter 124160, Minibatch Loss= 133.783508, Training Accuracy= 0.96875
# Iter 125440, Minibatch Loss= 55.583820, Training Accuracy= 0.98438
# Iter 126720, Minibatch Loss= 98.336273, Training Accuracy= 0.96875
# Iter 128000, Minibatch Loss= 42.961395, Training Accuracy= 0.98438
# Iter 129280, Minibatch Loss= 57.010628, Training Accuracy= 0.98438
# Optimization Finished!
# Testing Accuracy: 0.992188
